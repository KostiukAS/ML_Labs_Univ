# %% [markdown]
# Лабораторна робота 3

# %% [markdown]
# Зчитуємо дані:

# %%
import pandas as pd
avrMarchTemp = pd.read_csv('data.csv', delimiter = ',')

# %% [markdown]
# Форматування даних:

# %%
avrMarchTemp.columns = ['Date', 'Temperature', 'Anomaly']
avrMarchTemp.Date = avrMarchTemp.Date.floordiv(100)
avrMarchTemp.head()
# Out:
#    Date  Temperature  Anomaly
# 0  1895         39.6     -0.5
# 1  1896         38.2     -1.9
# 2  1897         33.0     -7.1
# 3  1898         37.1     -3.0
# 4  1899         37.9     -2.2

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    avrMarchTemp.Date.values.reshape(-1, 1), avrMarchTemp.Temperature.values,
    random_state=11)

# %%
x_train.shape
# Out:
# (96, 1)

# %%
x_test.shape
# Out:
# (33, 1)

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(X = x_train, y = y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([0.00458014])

# %%
linear_regression.intercept_
# Out:
# 31.293814298864127

# %%
predicted = linear_regression.predict(x_test)
expected = y_test
for p, e in zip(predicted[::5], expected[::5]):
    print(f'Predicted: {p:.2f}, expected: {e:.2f}')
# Out:
# Predicted: 39.97, expected: 39.60
# Predicted: 40.27, expected: 39.30
# Predicted: 40.33, expected: 42.60
# Predicted: 40.48, expected: 42.20
# Predicted: 40.49, expected: 36.70
# Predicted: 40.45, expected: 40.30
# Predicted: 40.07, expected: 32.80

# %%
predict = (lambda x: linear_regression.coef_ * x + linear_regression.intercept_)

predict(2024)
# Out:
# array([40.56401796])

# %%
predict(1890)
# Out:
# array([39.95027918])

# %%
import seaborn as sns

axes = sns.scatterplot(data=avrMarchTemp, x='Date', y='Temperature', 
                      hue='Temperature', palette='winter', legend=False)

axes.set_ylim(20, 60)

import numpy as np

x = np.array([min(avrMarchTemp.Date.values), max(avrMarchTemp.Date.values)])

y = predict(x)

import matplotlib.pyplot as plt

line = plt.plot(x, y)

# %%
np.random.seed(1)
X_xor = np.random.randn(200, 2)
y_xor = np.logical_xor(X_xor[:,0] > 0, X_xor[:,1] > 0)
y_xor = np.where(y_xor, 1, -1)
plt.scatter(X_xor[y_xor == 1, 0], X_xor[y_xor == 1, 1],
            c='b', marker='x', label='1')
plt.scatter(X_xor[y_xor == -1, 0], X_xor[y_xor == -1, 1],
            c='r', marker='s', label='-1')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.legend(loc='best')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), 
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim (xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    
    for idx, c1 in enumerate(np.unique(y)):
        plt.scatter(x=X[y == c1, 0],
                    y=X[y== c1, 1],
                    alpha = 0.8,
                    c = colors[idx],
                    marker = markers[idx],
                    label = c1,
                    edgecolor = 'black')

    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]
        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c = '',
                    edgecolor = 'black',
                    alpha=1.0,
                    linewidth = 1,
                    marker = 'o',
                    s=100,
                    label = 'Test data')

svm = SVC(kernel='rbf', random_state=1, gamma=0.10, C=10.0)
svm.fit(X_xor, y_xor)
plot_decision_regions(X_xor, y_xor, classifier=svm)
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\ssd\AppData\Local\Temp\ipykernel_22072\2940339079.py:21: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == c1, 0],

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data[:, [0, 2]]
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=11)

svm = SVC(kernel='rbf', random_state=11, gamma=0.10, C=10.0)
svm.fit(X_train, y_train)
plot_decision_regions(X_train, y_train, classifier=svm)
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\ssd\AppData\Local\Temp\ipykernel_22072\2940339079.py:21: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == c1, 0],

# %%
from sklearn.neighbors import KNeighborsClassifier

knc = KNeighborsClassifier(n_neighbors=5)
knc.fit(X_train, y_train)
plot_decision_regions(X_train, y_train, classifier=knc)
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\ssd\AppData\Local\Temp\ipykernel_22072\2940339079.py:21: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == c1, 0],

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
plot_decision_regions(X_train, y_train, classifier=gnb)
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\ssd\AppData\Local\Temp\ipykernel_22072\2940339079.py:21: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == c1, 0],
